# %% [markdown]
# ### Import data generation and model training

# %%
import sys
sys.path.append("..")  # So Python can find your scripts

from data.generate_data import generate_synthetic_data
from models.train_model import train_model
import pandas as pd
import seaborn as sns
import missingno as msno
import matplotlib.pyplot as plt

# %% [markdown]
# ### Generate Synthetic Data

# %%
df = generate_synthetic_data(n_samples=500, n_features=10, n_classes=2)
df.to_csv("../data/synthetic_data.csv", index=False)
df.head()
# Out:
#    feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0  -0.831822   3.778560  -0.916192  -0.690541  -0.715760  -0.825560
# 1  -0.066133  -0.440522  -0.436720   0.265878  -0.247026   0.140124
# 2  -0.437458  -1.526773  -0.887492   0.419532  -0.372833   0.013308
# 3  -0.526035  -0.811048   0.492019   0.420973   1.097153   0.174118
# 4  -0.305225  -0.054340  -1.065114  -1.311836  -0.186971  -0.011333
#
#    feature_6  feature_7  feature_8  feature_9  target
# 0  -4.887584  -0.783766  -2.016605  -0.067178       1
# 1   1.030778  -0.470042   0.527629   2.099722       1
# 2  -1.389822  -0.120948  -1.320396   0.722381       0
# 3   1.016694   0.698828   0.412293  -2.153343       1
# 4  -0.173507   0.010353  -0.125711  -0.609512       0

# %% [markdown]
# ### Load Data

# %% [markdown]
# ### Plot graph of feature_0 against feature_1

# %% [markdown]
# ### Visualize features

# %%
sns.pairplot(df.iloc[:, :5].assign(target=df['target']), hue="target")
plt.show()

# %% [markdown]
# ### Train model and view report

# %%
train_model(data_path="data/synthetic_data.csv")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.95      0.90        93
#            1       0.95      0.86      0.90       107
#
#     accuracy                           0.90       200
#    macro avg       0.90      0.90      0.90       200
# weighted avg       0.90      0.90      0.90       200
#
# Model saved to models/classifier.pkl

# %%
# Matrix plot
msno.matrix(df)
plt.show()
